# %%
import pandas as pd
import os

# %%
df = pd.read_csv('../dataset/nutrient_data_final.csv', sep=',')
name = list((set(df['이름'])))
name
# Out:
# ['Prebiotic Inulin-Fos Prebiotic Fiber',
#  '밀크씨슬+',
#  '더블 스트랭스 실리마린 밀크씨슬 300mg',
#  '프리미엄 밀크씨슬 골드',
#  '울트라 오메가3 500EPA / 250DHA',
#  'MSM with OptiMSM 1500mg',
#  '코엔자임 큐텐',
#  '눈건강 비타민A',
#  '비타민D 2000IU',
#  '콜라겐담다多',
#  '투 퍼 데이 태블릿',
#  '비타민C 1000mg',
#  'MSM Methylsulphonylmethane 1500mg',
#  '비오틴 biotin 10000mcg 타블렛',
#  '원스데일리 멀티비타민',
#  '락토핏 생유산균 플러스 포스트바이오틱스',
#  '비타민C1000 이지+비타민D',
#  '프리미엄 루테인 골드',
#  'L-Theanine 100mg Supports Relaxation',
#  'L-Theanine 200mg Supports Relaxation',
#  '에버콜라겐 타임 비오틴',
#  '다이어트 유산균 비에날씬 프로',
#  'S.A.T.®',
#  'LactoBif 프로바이오틱스 50억 LactoBif Probiotics 5 Billion CFU',
#  '올앳미 콜라겐3270',
#  '판토모나정',
#  '더블 스트랭스 테아닌 200mg',
#  'Gold C Vitamin C 1000 mg',
#  '칼슘앤마그네슘비타민D아연',
#  '메가도스C3000',
#  '비타민B1 B2 B6 B12 B군 컴플렉스',
#  '트리플 스트렝스 오메가3 피쉬오일',
#  '비타민B컴플렉스',
#  '아연50',
#  '콜레스테롤엔 모나콜린K 솔루션',
#  '더콜라겐필',
#  '네오랩 릴렉스케어',
#  'L-Carnitine 1000mg',
#  '비타민C 1000',
#  '뉴트립 맥스 릴렉스 테아닌',
#  '루테인오메가3',
#  '바이탈뷰티 슈퍼콜라겐 에센스',
#  '비타민D3 1000IU',
# ...

# %%
len(nutrient_list)
# Out:
# 155
